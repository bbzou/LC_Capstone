# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# from HelperFunctions import minibatch 
# %reload_ext autoreload
# %autoreload 2
from HelperFunctions import minibatch, dummify_columns, undummify, feature_standardize, label_encode_column, columns_of_type

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn import metrics

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor, AdaBoostRegressor
randomForest = RandomForestRegressor()
gbm = GradientBoostingRegressor()
abr = AdaBoostRegressor()
from xgboost import XGBRegressor
xgb = XGBRegressor()
from lightgbm import LGBMRegressor
lgb = LGBMRegressor()

# %% [markdown]
# # Helper Function

# %%
def adjust_prob(unsampled_df,sampled_df,sampled_prob): # sampled_df, sampled_prob can also be test_df, test_prob
    # turning the predicted probability into a dataframe with column name default_prob
    sample_prob_df=pd.DataFrame(sampled_prob[:,0],columns=['sampled_prob'])
    # find actual default rate for each class
    grade_rate=unsampled_df.groupby('grade')['loan_status'].apply(lambda x:(x=='Default').sum()/x.count())
    grade_rate_dict=grade_rate.to_dict()
    # mapping the unsampled_df default rates to the test_df=sampled_df
    # and then getting the array of default_rates in the test_df
    sampled_df['default_rate']=sampled_df['grade'].map(grade_rate_dict)
    sampled_df.reset_index(drop=True, inplace=True)
    sample_prob_df.reset_index(drop=True, inplace=True)
    pre_adjust_df=pd.concat([sampled_df,sample_prob_df],axis=1)
    # Adjusting the default_probability to the true probability (accounting for down/up sampling)    
    sampled_frac=0.5
    real_prob=[]
    for row in pre_adjust_df.loc[:,['default_rate','sampled_prob']].iterrows():
        beta=sampled_frac/(1-row[1]['default_rate'])
        real_prob.append(beta*row[1]['sampled_prob']/((beta-1)*row[1]['sampled_prob']+1))
        #     prob=1/(1+(1/original_fraction-1)/(1/sampled_fraction-1)*(1/sampled_prob-1))
    a=pd.DataFrame(real_prob,columns=['actual_prob'])
    b=pd.DataFrame(sampled_prob[:,0],columns=['downsampled_prob'])
    return pd.concat([a,b],axis=1)

# %%
df=pd.read_csv('down_sampled_df_v2.csv',index_col='id')
pre_df=pd.read_csv('pre_downsample_df.csv',index_col='id')
# Out:
# /home/auscheng/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
drop_list=['sub_grade','issue_d','zip_code','addr_state','RANDOM']
df.drop(drop_list,axis=1,inplace=True)

# %%
x_train=df.drop(['loan_status','return_rate'],axis=1)
y_train=df.loan_status

# %%
cat_list=columns_of_type(x_train,'string')
cont_list=columns_of_type(x_train,'number')

# %%
dum_df=dummify_columns(x_train,cat_list)

# %% [markdown]
# # Standardize Features

# %%
dum_df=dum_df.apply(lambda x:feature_standardize(x,scaleType='standardize'),axis=0)

# %%
dum_df.head()
# Out:
#         funded_amnt      term  int_rate  emp_length  annual_inc       dti  \
# id
# 65426     -1.250700 -0.742457 -0.923823   -0.815739   -0.245301 -0.762739
# 67503     -0.567841 -0.742457 -1.444537   -0.815739   -0.350907 -0.363714
# 69550     -0.431270  1.346879 -0.068218   -0.466930   -0.614923 -0.209895
# 70348     -0.613365 -0.742457 -0.688991    0.230688    0.229927 -0.969037
# 102823    -1.193795 -0.742457 -0.648151   -0.815739   -1.010947 -0.900271
#
#         delinq_2yrs  credit_age_years  mths_since_last_delinq  \
# id
# 65426     -0.375378         -0.230649                0.905157
# 67503     -0.375378          0.292931               -1.028789
# 69550     -0.375378         -1.517537               -1.028789
# 70348     -0.375378         -0.732165                1.036797
# 102823    -0.375378         -1.847393                0.905157
#
#         mths_since_last_derog_record  derog_records  revol_util  total_acc  \
# id
# 65426                       1.879737      -0.346692    0.382824   0.726010
# 67503                      -0.488236      -0.346692   -0.989701   2.077014
# 69550                      -0.488236      -0.346692    0.398692  -1.131621
# 70348                       2.029068       1.064450    0.105146   0.219383
# 102823                      1.879737      -0.346692    0.583811  -1.553810
#
#         collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 65426                    -0.125225                     -0.62855
# 67503                    -0.125225                     -0.62855
# 69550                    -0.125225                     -0.62855
# 70348                    -0.125225                     -0.62855
# 102823                   -0.125225                     -0.62855
#
#         acc_now_delinq  collection_amt  install_util  all_util  rev_credit  \
# id
# 65426        -0.068812       -1.269208     -0.748211  -0.83501   -1.277651
# 67503        -0.068812       -1.269208     -0.748211  -0.83501   -1.277651
# 69550        -0.068812       -1.269208     -0.748211  -0.83501   -1.277651
# 70348        -0.068812       -1.269208     -0.748211  -0.83501   -1.277651
# 102823       -0.068812       -1.269208     -0.748211  -0.83501   -1.277651
#
#         inq_last_12m  chargeoff_within_12_mths  delinq_amnt  \
# id
# 65426      -0.835322                 -0.087661    -0.020591
# 67503      -0.835322                 -0.087661    -0.020591
# 69550      -0.835322                 -0.087661    -0.020591
# 70348      -0.835322                 -0.087661    -0.020591
# 102823     -0.835322                 -0.087661    -0.020591
#
#         mths_since_RecentAcc_opened  all_accs_120days+_PastDue_ever  \
# id
# 65426                     -4.513523                       -4.516475
# 67503                     -4.513523                       -4.516475
# 69550                     -4.513523                       -4.516475
# 70348                     -4.513523                       -4.516475
# 102823                    -4.513523                       -4.516475
#
#         accs_90days+_PastDue_24m  accs_opened_past_12m  pct_acc_nvr_dlq  \
# id
# 65426                   -4.51655             -4.516381        -4.505566
# 67503                   -4.51655             -4.516381        -4.505566
# 69550                   -4.51655             -4.516381        -4.505566
# 70348                   -4.51655             -4.516381        -4.505566
# 102823                  -4.51655             -4.516381        -4.505566
#
#         pub_rec_bankruptcies  tax_liens  total_credit  install_credit  \
# id
# 65426              -0.379280  -0.115042     -1.041822       -1.092842
# 67503              -0.379280  -0.115042     -1.041822       -1.092842
# 69550              -0.379280  -0.115042     -1.041822       -1.092842
# 70348               2.107324  -0.115042     -1.041822       -1.092842
# 102823             -0.379280  -0.115042     -1.041822       -1.092842
#
#             fico  Outstanding_mortgage_debt  revol_frac  install_frac  \
# id
# 65426   1.199346                  -0.647401   -4.516561     -4.516561
# 67503   2.908357                  -0.647401   -4.516561     -4.516561
# 69550  -0.129885                  -0.647401   -4.516561     -4.516561
# 70348  -0.699555                  -0.647401   -4.516561     -4.516561
# 102823 -1.079335                  -0.647401   -4.516561     -4.516561
#
#         mort_frac  card_frac  active_card_frac  active_revol_frac  \
# id
# 65426   -5.407963  -4.515584          -4.37633          -4.515584
# 67503   -5.407963  -4.515584          -4.37633          -4.515584
# 69550   -5.407963  -4.515584          -4.37633          -4.515584
# 70348   -5.407963  -4.515584          -4.37633          -4.515584
# 102823  -5.407963  -4.515584          -4.37633          -4.515584
#
#         active_install_frac  open_revol_frac  good_acc_frac  loan_duration  \
# id
# 65426             -0.814373        -4.515584      -5.005319       0.243424
# 67503             -0.814373        -4.515584      -5.005319       0.736064
# 69550             -0.814373        -4.515584      -5.005319       2.610238
# 70348             -0.814373        -4.515584      -5.005319       0.570066
# 102823            -0.814373        -4.515584      -5.005319       1.386670
#
#         grade__B  grade__C  grade__D  grade__E  grade__F  grade__G  \
# id
# 65426   2.033927 -0.684839 -0.544853 -0.394054 -0.239771  -0.13152
# 67503  -0.491660 -0.684839 -0.544853 -0.394054 -0.239771  -0.13152
# 69550  -0.491660 -0.684839  1.835357 -0.394054 -0.239771  -0.13152
# 70348  -0.491660  1.460198 -0.544853 -0.394054 -0.239771  -0.13152
# 102823 -0.491660 -0.684839  1.835357 -0.394054 -0.239771  -0.13152
#
#         home_ownership__MORTGAGE  home_ownership__NONE  home_ownership__OTHER  \
# id
# 65426                   1.095325              -0.00621               -0.01242
# 67503                   1.095325              -0.00621               -0.01242
# 69550                  -0.912971              -0.00621               -0.01242
# 70348                  -0.912971              -0.00621               -0.01242
# 102823                 -0.912971              -0.00621               -0.01242
#
#         home_ownership__OWN  home_ownership__RENT  \
# id
# 65426             -0.348754             -0.880260
# 67503             -0.348754             -0.880260
# 69550             -0.348754              1.136028
# 70348             -0.348754              1.136028
# 102823            -0.348754              1.136028
#
#         verification_status__Source Verified  verification_status__Verified  \
# id
# 65426                              -0.805821                      -0.756006
# 67503                              -0.805821                      -0.756006
# 69550                              -0.805821                      -0.756006
# 70348                              -0.805821                      -0.756006
# 102823                             -0.805821                      -0.756006
#
#         purpose__credit_card  purpose__debt_consolidation  \
# id
# 65426              -0.478773                    -1.247711
# 67503              -0.478773                     0.801468
# 69550              -0.478773                     0.801468
# 70348              -0.478773                     0.801468
# 102823             -0.478773                     0.801468
#
#         purpose__educational  purpose__home_improvement  purpose__house  \
# id
# 65426              -0.014564                  -0.249595       -0.080503
# 67503              -0.014564                  -0.249595       -0.080503
# 69550              -0.014564                  -0.249595       -0.080503
# 70348              -0.014564                  -0.249595       -0.080503
# 102823             -0.014564                  -0.249595       -0.080503
#
#         purpose__major_purchase  purpose__medical  purpose__moving  \
# id
# 65426                 -0.145336         -0.112298        -0.092599
# 67503                 -0.145336         -0.112298        -0.092599
# 69550                 -0.145336         -0.112298        -0.092599
# 70348                 -0.145336         -0.112298        -0.092599
# 102823                -0.145336         -0.112298        -0.092599
#
#         purpose__other  purpose__renewable_energy  purpose__small_business  \
# id
# 65426        -0.258114                  -0.028125                -0.129765
# 67503        -0.258114                  -0.028125                -0.129765
# 69550        -0.258114                  -0.028125                -0.129765
# 70348        -0.258114                  -0.028125                -0.129765
# 102823       -0.258114                  -0.028125                -0.129765
#
#         purpose__vacation  purpose__wedding  initial_list_status__w  \
# id
# 65426           -0.084875         -0.041921               -1.139686
# 67503           -0.084875         -0.041921               -1.139686
# 69550           -0.084875         -0.041921               -1.139686
# 70348           -0.084875         -0.041921               -1.139686
# 102823          -0.084875         -0.041921               -1.139686
#
#         application_type__Joint App
# id
# 65426                     -0.147192
# 67503                     -0.147192
# 69550                     -0.147192
# 70348                     -0.147192
# 102823                    -0.147192

# %% [markdown]
# # Stochastic Gradient Descent: Not good

# %%
# def acc_model(params):
#     clf = SGDClassifier(loss='log',max_iter=1000,tol=1e-3,random_state=0,**params)
#     return cross_val_score(clf, dum_df, y_train,cv=5,n_jobs=-1,scoring='accuracy').mean()

# alpha_range=np.logspace(-5,4,10)
# penalty_range=['l1','l2']

# param_space = {
#     'alpha':hp.choice('alpha',alpha_range),
#     'penalty': hp.choice('penalty', penalty_range)}

# best = acc_model({'alpha':alpha_range[0],'penalty':penalty_range[0]})
# def f(params):
#     global best
#     acc_score = acc_model(params)
#     if acc_score > best:
#         best = acc_score
#     print ('new best:', best, params)
#     return {'loss': -1*acc_score, 'status': STATUS_OK}

# trials = Trials()
# best = fmin(f, param_space, algo=tpe.suggest, max_evals=100, trials=trials)
# print ('best:')
# print (best)
# Out:
# new best:
# 0.5025832830454263
# {'alpha': 0.1, 'penalty': 'l1'}
# new best:
# 0.5025832830454263
# {'alpha': 10000.0, 'penalty': 'l2'}
# new best:
# 0.5025832830454263
# {'alpha': 0.001, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 1e-05, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.0001, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 1.0, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 10.0, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 1.0, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 100.0, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 0.01, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 0.0001, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 10000.0, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 10.0, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.01, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 0.001, 'penalty': 'l1'}
# new best:
# 0.5103134592737637
# {'alpha': 10000.0, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.0001, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.0001, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.0001, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 1e-05, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 100.0, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.001, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 1e-05, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5103134592737637
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 100.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 0.01, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10000.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.001, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 10.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1e-05, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.01, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 100.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.0001, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.001, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1e-05, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.01, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.0001, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 100.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.001, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1e-05, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.01, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 10000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.0001, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 100.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 0.001, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1e-05, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 0.01, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1000.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 0.1, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 10000.0, 'penalty': 'l1'}
# new best:
# 0.5217456560771716
# {'alpha': 1.0, 'penalty': 'l2'}
# new best:
# 0.5217456560771716
# {'alpha': 100.0, 'penalty': 'l2'}
# 100%|██████████| 100/100 [01:52<00:00,  1.36it/s, best loss: -0.5217456560771716]
# best:
# {'alpha': 5, 'penalty': 1}

# %% [markdown]
# # Logit Classifier: NOT GOOD FOR -999 IMPUTATION! because analytical equation. Also, the data is highly likely to be non-linear. Stick with tree!

# %%
# def acc_model(params):
#     clf = LogisticRegression(**params)
#     return cross_val_score(clf, dum_df, y_train,cv=5,n_jobs=-1,scoring='accuracy').mean()

# C_range=np.logspace(0,5,3)
# penalty_range=['l1','l2']

# param_space = {
#     'C': hp.choice('C',C_range),
#     'penalty': hp.choice('penalty', penalty_range)}

# best = acc_model({'C':C_range[0],'penalty':penalty_range[0]})
# def f(params):
#     global best
#     acc_score = acc_model(params)
#     if acc_score > best:
#         best = acc_score
#     print ('new best:', best, params)
#     return {'loss': -1*acc_score, 'status': STATUS_OK}

# trials = Trials()
# best = fmin(f, param_space, algo=tpe.suggest, max_evals=15, trials=trials)
# print ('best:')
# print (best)
# Out:
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l1'}
# new best:
# 0.4964717112521805
# {'C': 316.22776601683796, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l1'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 100000.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l1'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 316.22776601683796, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 100000.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 316.22776601683796, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 316.22776601683796, 'penalty': 'l1'}
# new best:
# 0.4964717112521805
# {'C': 100000.0, 'penalty': 'l2'}
# new best:
# 0.4964717112521805
# {'C': 1.0, 'penalty': 'l2'}
# 100%|██████████| 15/15 [28:54<00:00, 131.83s/it, best loss: -0.4964717112521805]
# best:
# {'C': 0, 'penalty': 1}

# %%
# logit=LogisticRegression(C=C_range[best['C']],penalty=penalty_range[best['penalty']])
# logit.fit(dum_df,y_train)
# sampled_prob=logit.predict_proba(dum_df) #[Default,Fully Paid]

# print('best cv score:', logit.score(dum_df,y_train))
# from sklearn.metrics import confusion_matrix
# confusion_matrix(y_train, logit.predict(dum_df))
# Out:
# /home/auscheng/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# best cv score: 0.5644471005552129
# array([[15644, 10426],
#        [12167, 13635]])

# %%
adjust_prob(pre_df,df,sampled_prob)
# Out:
#        actual_prob  downsampled_prob
# 0         0.166161          0.272580
# 1         0.121002          0.205632
# 2         0.105944          0.182225
# 3         0.147239          0.245102
# 4         0.131326          0.221357
# 5         0.122586          0.208062
# 6         0.154080          0.255130
# 7         0.151165          0.250871
# 8         0.000081          0.000153
# 9         0.111492          0.190916
# 10        0.000116          0.000218
# 11        0.107220          0.184230
# 12        0.102812          0.177285
# 13        0.167444          0.274414
# 14        0.104266          0.179582
# 15        0.111219          0.190489
# 16        0.169656          0.277569
# 17        0.191911          0.308717
# 18        0.134754          0.226523
# 19        0.137694          0.230931
# 20        0.132842          0.223645
# 21        0.153651          0.254504
# 22        0.153595          0.254422
# 23        0.140481          0.235091
# 24        0.140893          0.235704
# 25        0.175561          0.285936
# 26        0.107722          0.185019
# 27        0.141087          0.235993
# 28        0.142488          0.238075
# 29        0.114801          0.196060
# ...            ...               ...
# 51842     0.543259          0.546984
# 51843     0.586646          0.590285
# 51844     0.569793          0.573472
# 51845     0.550822          0.554537
# 51846     0.603890          0.607479
# 51847     0.540507          0.544237
# 51848     0.558402          0.562104
# 51849     0.513110          0.516863
# 51850     0.544986          0.548709
# 51851     0.563303          0.566995
# 51852     0.583617          0.587264
# 51853     0.586842          0.590480
# 51854     0.571634          0.575309
# 51855     0.540791          0.544520
# 51856     0.606821          0.610400
# 51857     0.539642          0.543372
# 51858     0.610748          0.614314
# 51859     0.553635          0.557345
# 51860     0.591002          0.594629
# 51861     0.610330          0.613898
# 51862     0.615930          0.619478
# 51863     0.599434          0.603036
# 51864     0.656692          0.660071
# 51865     0.600799          0.604397
# 51866     0.620647          0.624178
# 51867     0.546214          0.549936
# 51868     0.537974          0.541706
# 51869     0.647112          0.650535
# 51870     0.596305          0.599917
# 51871     0.663603          0.666949
#
# [51872 rows x 2 columns]
