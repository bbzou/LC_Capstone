# %%
import numpy as np
import pandas as pd
import sklearn.feature_selection as fs
from sklearn import preprocessing, ensemble

# %reload_ext autoreload
# %autoreload 2
from function_library import label_encoder

# %%
## load data
file_path = '../Cleaned Datasets/Sampled Dataset_Balanced.csv.gz'
data = pd.read_csv(file_path, compression = 'gzip').sort_values(by = 'issue_d', ascending = True)
pd.set_option("display.max_columns", data.shape[1])

## list of features to use from feature selection
lst_final = ['mths_since_last_delinq',
 'grade',     ## to be dropped later, manually added only for weighting purpose
 'sub_grade',
 'home_ownership',
 'total_rev_hi_lim',
 'annual_inc',
 'term',
 'active_ins_acct_frac',
 'fico_score',
 'funded_amnt',
 'all_util',
 'emp_length',
 'revol_util',
 'treasury_rate',
 'credit_hist',
 'int_rate',
 'purpose',
 'dti',
 'tot_hi_cred_lim',
 'total_acc',
 'tot_cur_bal',
 'total_il_high_credit_limit',
 'il_util',
 'addr_state',
 'total_bc_limit',
 'unemp_rate_3mon',
 'num_il_tl']

# %%
## get classifier and regressor targets
df = data.copy().set_index('issue_d', drop = True)
# df_status = df['loan_status']
# df_return = df['return_rate']

## create dataframes for classification and regression separately
df_class = df[lst_final + ['loan_status']]

## include the loan status column to split dataset into default and fully paid
df_regress = df[lst_final + ['return_rate', 'loan_status']]
## default subset
df_regress_d = df_regress[df_regress.loan_status == 'Default'].drop('loan_status', axis = 1)
## fully paid subset
df_regress_fp = df_regress[df_regress.loan_status == 'Fully Paid'].drop('loan_status', axis = 1)

# %%
df_regress.shape
# Out:
# (132894, 29)

# %% [markdown]
# ## Grid Search with Customized Weighted Score Metric On Random Forest with Time Series

# %%
# from sklearn.metrics import accuracy_score, r2_score
from sklearn.metrics.scorer import make_scorer
from sklearn.model_selection import GridSearchCV
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import accuracy_score, r2_score

## define an accuracy scorer with grade weight
def grade_weighted_accuracy(y_true, y_pred, sample_weight):
    
    weighted_acc = accuracy_score(y_true, y_pred, normalize = True,
                                sample_weight = sample_weight.loc[y_true.index.values].values.reshape(-1)
                                 )
    return weighted_acc

## define R^2 scorer with grade weight
def grade_weighted_r2(y_true,y_pred,sample_weight):

    weighted_r2 = r2_score(y_true, y_pred,
                         sample_weight=sample_weight.loc[y_true.index.values].values.reshape(-1))
    return weighted_r2

# %%
## grade weight dictionary
grade_weight_ab = {'A': 100,
                  'B': 100,
                  'C': 1,
                  'D': 1,
                  'E': 1,
                  'F': 1,
                  'G': 1}

grade_weight_cd = {'A': 1,
                  'B': 1,
                  'C': 100,
                  'D': 100,
                  'E': 1,
                  'F': 1,
                  'G': 1}

grade_weight_efg = {'A': 1,
                  'B': 1,
                  'C': 1,
                  'D': 1,
                  'E': 100,
                  'F': 100,
                  'G': 100}

# %% [markdown]
# ### Find the best RF model in each time window (non-overlapping) with Grid Search
#
# - Classifier: combined dataframe
# - Regressor: default only
# - Regressor: fully paid only

# %%
## get the lsit of possible time windows
lst_time = data.issue_d.unique().tolist()

## width and shift length of each time window -> no overlap btwn windows
window = 3

# %% [markdown]
# ##### Classifier Models with Time Series

# %%
# %%time

## incorporate the weights into the dataframes
df_class['weight'] = df_class.grade.map(grade_weight_efg)

## label encode non-numeric features
# df_class_le = df_class.copy()
df_class_le = label_encoder(df_class)

## split feature and target dataframes - note: weight is the last column
# classifier
df_c_x = df_class_le[set(df_class_le.columns) - set(['loan_status'])].drop('grade', axis = 1)
df_c_y = df_class_le.loan_status

## open and create a pickle file to store models
filename_class = './Classifier_EFG.pkl'
file = open(filename_class, 'wb')

## loop through each time window
for i in range(0, len(lst_time) - window + 1, window):
    # months in the ith time window
    lst_window = lst_time[i : i + window]
    # subset of dataframe
    df_window_x = df_c_x.loc[lst_window].reset_index(drop = True)
    df_window_y = df_c_y.loc[lst_window].reset_index(drop = True)
    
    # a dataframe of the grade weights
    df_grade_weight = pd.DataFrame(df_window_x.weight, index = df_window_x.index)
    
    score_params = {"sample_weight": df_grade_weight}

    grade_weighted_scorer = make_scorer(score_func = grade_weighted_accuracy,
                                        greater_is_better = True,
                                        needs_proba = False,
                                        needs_threshold = False,
                                        **score_params)
    grid_para_rf = {
        'n_estimators': [5, 10, 15, 20, 25, 30],
        'max_depth': [None],
        'max_features': ['auto'],
        'min_samples_leaf': range(5, 15),
        'warm_start': [False, True]}
     
    gs_rf = GridSearchCV(estimator = ensemble.RandomForestClassifier(),\
                                      param_grid = grid_para_rf,\
                                      scoring = grade_weighted_scorer,\
                                      n_jobs = -1, cv = 5, return_train_score = False)
    
    # fit the grid search
    gs_rf.fit(df_window_x, df_window_y)
    
    # save the model using pickle
    pickle.dump(gs_rf, file)
    
    # status report
    print('Saved the model for period {} to {}. The best score is {}.'.\
          format(lst_window[0], lst_window[-1], np.round(gs_rf.best_score_, 6)))
    print('-' * 88)
    
file.close()
# Out:
# Saved the model for period 2007-10-01 to 2007-12-01. The best score is 0.778878.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2008-01-01 to 2008-03-01. The best score is 0.66134.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2008-04-01 to 2008-06-01. The best score is 0.675306.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2008-07-01 to 2008-10-01. The best score is 0.85.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2008-11-01 to 2009-01-01. The best score is 0.672449.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2009-02-01 to 2009-04-01. The best score is 0.774957.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2009-05-01 to 2009-07-01. The best score is 0.55102.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2009-08-01 to 2009-10-01. The best score is 0.788512.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2009-11-01 to 2010-01-01. The best score is 0.743938.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2010-02-01 to 2010-04-01. The best score is 0.754466.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2010-05-01 to 2010-07-01. The best score is 0.685585.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2010-08-01 to 2010-10-01. The best score is 0.728693.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2010-11-01 to 2011-01-01. The best score is 0.645633.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2011-02-01 to 2011-04-01. The best score is 0.654953.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2011-05-01 to 2011-07-01. The best score is 0.698032.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2011-08-01 to 2011-10-01. The best score is 0.543455.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2011-11-01 to 2012-01-01. The best score is 0.666779.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2012-02-01 to 2012-04-01. The best score is 0.530286.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2012-05-01 to 2012-07-01. The best score is 0.640683.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2012-08-01 to 2012-10-01. The best score is 0.591685.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2012-11-01 to 2013-01-01. The best score is 0.55404.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2013-02-01 to 2013-04-01. The best score is 0.560785.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2013-05-01 to 2013-07-01. The best score is 0.542329.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2013-08-01 to 2013-10-01. The best score is 0.575392.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2013-11-01 to 2014-01-01. The best score is 0.550728.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2014-02-01 to 2014-04-01. The best score is 0.516692.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2014-05-01 to 2014-07-01. The best score is 0.532798.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2014-08-01 to 2014-10-01. The best score is 0.448144.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2014-11-01 to 2015-01-01. The best score is 0.542475.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2015-02-01 to 2015-04-01. The best score is 0.556073.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2015-05-01 to 2015-07-01. The best score is 0.572412.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2015-08-01 to 2015-10-01. The best score is 0.567656.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2015-11-01 to 2016-01-01. The best score is 0.580551.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2016-02-01 to 2016-04-01. The best score is 0.55906.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2016-05-01 to 2016-07-01. The best score is 0.524764.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2016-08-01 to 2016-10-01. The best score is 0.445981.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2016-11-01 to 2017-01-01. The best score is 0.503002.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2017-02-01 to 2017-04-01. The best score is 0.537089.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2017-05-01 to 2017-07-01. The best score is 0.533409.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2017-08-01 to 2017-10-01. The best score is 0.538779.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2017-11-01 to 2018-01-01. The best score is 0.633172.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2018-02-01 to 2018-04-01. The best score is 0.635498.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2018-05-01 to 2018-07-01. The best score is 0.622028.
# ----------------------------------------------------------------------------------------
# Saved the model for period 2018-08-01 to 2018-10-01. The best score is 0.570502.
# ----------------------------------------------------------------------------------------
# Wall time: 18min 41s

# %% [markdown]
# ##### Regressor Models with Time Series

# %%
df_r_d_x.head(3)
# Out:
#             weight    dti  total_il_high_credit_limit  total_bc_limit  \
# issue_d
# 2007-10-01       1   3.26                      -999.0          -999.0
# 2007-10-01       1   3.01                      -999.0          -999.0
# 2007-11-01       1  16.97                      -999.0          -999.0
#
#             purpose  addr_state  il_util  unemp_rate_3mon  all_util  \
# issue_d
# 2007-10-01        9          24   -999.0             5.20    -999.0
# 2007-10-01        2           9   -999.0             4.47    -999.0
# 2007-11-01        2          47   -999.0             4.37    -999.0
#
#             mths_since_last_delinq  funded_amnt  int_rate  total_acc  \
# issue_d
# 2007-10-01                    22.0       4650.0     10.28       25.0
# 2007-10-01                     0.0       4900.0     13.75        5.0
# 2007-11-01                     0.0      15450.0     10.91       39.0
#
#             total_rev_hi_lim  tot_cur_bal  num_il_tl  term  treasury_rate  \
# issue_d
# 2007-10-01            -999.0       -999.0     -999.0    36           4.01
# 2007-10-01            -999.0       -999.0     -999.0    36           4.01
# 2007-11-01            -999.0       -999.0     -999.0    36           3.35
#
#             annual_inc  tot_hi_cred_lim  emp_length  sub_grade  fico_score  \
# issue_d
# 2007-10-01     45600.0           -999.0          10         10       687.0
# 2007-10-01     43500.0           -999.0           4         21       647.0
# 2007-11-01    120000.0           -999.0           7         12       697.0
#
#             credit_hist  active_ins_acct_frac  home_ownership  revol_util
# issue_d
# 2007-10-01    17.926027                -999.0               1        35.0
# 2007-10-01     3.501370                -999.0               5        90.1
# 2007-11-01    26.520548                -999.0               5        44.5

# %%
# %%time

## incorporate the weights into the dataframes
df_regress_d['weight'] = df_regress_d.grade.map(grade_weight_efg)
df_regress_fp['weight'] = df_regress_fp.grade.map(grade_weight_efg)

## label encode non-numeric features
df_regress_d_le = label_encoder(df_regress_d)
df_regress_fp_le = label_encoder(df_regress_fp)

## split feature and target dataframes - note: weight is the last column
# regressor - default
df_r_d_x = df_regress_d_le[set(df_regress_d.columns) - set(['return_rate'])].drop('grade', axis = 1)
df_r_d_y = df_regress_d_le.return_rate

# regressor - fully paid
df_r_fp_x = df_regress_fp_le[set(df_regress_fp.columns) - set(['return_rate'])].drop('grade', axis = 1)
df_r_fp_y = df_regress_fp_le.return_rate

## open and create a pickle file to store models
filename_regress_def = './Regressor_Default_EFG.pkl'
filename_regress_fp = './Regressor_Fully Paid_EFG.pkl'


#### search for the best classifiers
file = open(filename_regress_def, 'wb')

## loop through each time window
for i in range(0, len(lst_time) - window + 1, window):
    # months in the ith time window
    lst_window = lst_time[i : i + window]
    # subset of dataframe
    df_window_x = df_r_d_x.loc[lst_window].reset_index(drop = True)
    df_window_y = df_r_d_y.loc[lst_window].reset_index(drop = True)
    
    # a dataframe of the grade weights
    df_grade_weight = pd.DataFrame(df_window_x.weight, index = df_window_x.index)
    
    score_params = {"sample_weight": df_grade_weight}

    grade_weighted_scorer = make_scorer(score_func = grade_weighted_r2,
                                        greater_is_better = True,
                                        needs_proba = False,
                                        needs_threshold = False,
                                        **score_params)
    grid_para_rf = {
        'n_estimators': [3, 5, 10, 15, 20, 25, 30, 35, 40],
        'max_depth': [None],
        'max_features': ['auto'],
        'min_samples_leaf': range(2, 20),
        'warm_start': [False, True]}
     
    gs_rf = GridSearchCV(estimator = ensemble.RandomForestRegressor(),\
                                      param_grid = grid_para_rf,\
                                      scoring = grade_weighted_scorer,\
                                      n_jobs = -1, cv = 5, return_train_score = False)
    
    # fit the grid search
    gs_rf.fit(df_window_x, df_window_y)
    
    # save the model using pickle
    pickle.dump(gs_rf, file)
    
    # status report
    print('Saved the default model for period {} to {}. The best score is {}.'.\
          format(lst_window[0], lst_window[-1], np.round(gs_rf.best_score_, 6)))
    print(gs_rf.best_params_)
    print('-' * 100)
    
file.close()


#### search for the best regressors
file = open(filename_regress_fp, 'wb')

## loop through each time window
for i in range(0, len(lst_time) - window + 1, window):
    # months in the ith time window
    lst_window = lst_time[i : i + window]
    # subset of dataframe
    df_window_x = df_r_fp_x.loc[lst_window].reset_index(drop = True)
    df_window_y = df_r_fp_y.loc[lst_window].reset_index(drop = True)
    
    # a dataframe of the grade weights
    df_grade_weight = pd.DataFrame(df_window_x.weight, index = df_window_x.index)
    
    score_params = {"sample_weight": df_grade_weight}

    grade_weighted_scorer = make_scorer(score_func = grade_weighted_r2,
                                        greater_is_better = True,
                                        needs_proba = False,
                                        needs_threshold = False,
                                        **score_params)
    grid_para_rf = {
        'n_estimators': [3, 5, 10, 15, 20, 25, 30, 35, 40],
        'max_depth': [None],
        'max_features': ['auto'],
        'min_samples_leaf': range(2, 20),
        'warm_start': [False, True]}
     
    gs_rf = GridSearchCV(estimator = ensemble.RandomForestRegressor(),\
                                      param_grid = grid_para_rf,\
                                      scoring = grade_weighted_scorer,\
                                      n_jobs = -1, cv = 5, return_train_score = False)
    
    # fit the grid search
    gs_rf.fit(df_window_x, df_window_y)
    
    # save the model using pickle
    pickle.dump(gs_rf, file)
    
    # status report
    print('Saved the fully-paid model for period {} to {}. The best score is {}.'.\
          format(lst_window[0], lst_window[-1], np.round(gs_rf.best_score_, 6)))
    print(gs_rf.best_params_)
    print('-' * 100)
    
file.close()
# Out:
# Saved the default model for period 2007-10-01 to 2007-12-01. The best score is nan.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2008-01-01 to 2008-03-01. The best score is -1.187848.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2008-04-01 to 2008-06-01. The best score is -13.429246.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2008-07-01 to 2008-10-01. The best score is -380894.774777.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2008-11-01 to 2009-01-01. The best score is -0.612017.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2009-02-01 to 2009-04-01. The best score is -1.343247.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 10, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2009-05-01 to 2009-07-01. The best score is -0.050694.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2009-08-01 to 2009-10-01. The best score is -0.530303.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2009-11-01 to 2010-01-01. The best score is -2.035007.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2010-02-01 to 2010-04-01. The best score is -0.523958.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 5, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2010-05-01 to 2010-07-01. The best score is -1.008802.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 9, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2010-08-01 to 2010-10-01. The best score is 0.09861.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2010-11-01 to 2011-01-01. The best score is -0.163571.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2011-02-01 to 2011-04-01. The best score is -0.061739.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 17, 'n_estimators': 5, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2011-05-01 to 2011-07-01. The best score is -0.014196.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2011-08-01 to 2011-10-01. The best score is -0.141254.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2011-11-01 to 2012-01-01. The best score is 0.073937.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2012-02-01 to 2012-04-01. The best score is 0.07463.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 5, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2012-05-01 to 2012-07-01. The best score is 0.03404.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2012-08-01 to 2012-10-01. The best score is 0.044755.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 5, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2012-11-01 to 2013-01-01. The best score is 0.023258.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 5, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2013-02-01 to 2013-04-01. The best score is 0.047253.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2013-05-01 to 2013-07-01. The best score is 0.01548.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 30, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2013-08-01 to 2013-10-01. The best score is -0.026649.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 9, 'n_estimators': 35, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2013-11-01 to 2014-01-01. The best score is 0.007843.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 40, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2014-02-01 to 2014-04-01. The best score is 0.007637.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 11, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2014-05-01 to 2014-07-01. The best score is -0.009739.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 15, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2014-08-01 to 2014-10-01. The best score is 0.007399.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 17, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2014-11-01 to 2015-01-01. The best score is 0.024507.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2015-02-01 to 2015-04-01. The best score is -0.007754.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 40, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2015-05-01 to 2015-07-01. The best score is -0.016005.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 15, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2015-08-01 to 2015-10-01. The best score is 0.041993.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 14, 'n_estimators': 30, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2015-11-01 to 2016-01-01. The best score is -0.002688.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 40, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2016-02-01 to 2016-04-01. The best score is 0.004224.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 12, 'n_estimators': 40, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2016-05-01 to 2016-07-01. The best score is 0.044268.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 13, 'n_estimators': 15, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2016-08-01 to 2016-10-01. The best score is -0.022156.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 25, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2016-11-01 to 2017-01-01. The best score is -0.014948.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 13, 'n_estimators': 25, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2017-02-01 to 2017-04-01. The best score is -0.023512.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 9, 'n_estimators': 30, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2017-05-01 to 2017-07-01. The best score is -0.019253.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 35, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2017-08-01 to 2017-10-01. The best score is -0.027417.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 6, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2017-11-01 to 2018-01-01. The best score is -0.044934.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 12, 'n_estimators': 5, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2018-02-01 to 2018-04-01. The best score is -0.157231.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 35, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2018-05-01 to 2018-07-01. The best score is -0.624566.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 5, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the default model for period 2018-08-01 to 2018-10-01. The best score is -15.462322.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 25, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2007-10-01 to 2007-12-01. The best score is nan.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2008-01-01 to 2008-03-01. The best score is -0.302519.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 7, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2008-04-01 to 2008-06-01. The best score is -1.017469.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2008-07-01 to 2008-10-01. The best score is -1.780573.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2008-11-01 to 2009-01-01. The best score is -0.33129.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2009-02-01 to 2009-04-01. The best score is -1.378098.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 6, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2009-05-01 to 2009-07-01. The best score is 0.116327.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2009-08-01 to 2009-10-01. The best score is -0.350769.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 9, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2009-11-01 to 2010-01-01. The best score is 0.501928.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 25, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2010-02-01 to 2010-04-01. The best score is 0.277782.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 17, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2010-05-01 to 2010-07-01. The best score is 0.273293.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 13, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2010-08-01 to 2010-10-01. The best score is 0.457188.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 5, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2010-11-01 to 2011-01-01. The best score is 0.438775.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 12, 'n_estimators': 5, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2011-02-01 to 2011-04-01. The best score is 0.240068.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2011-05-01 to 2011-07-01. The best score is 0.282607.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2011-08-01 to 2011-10-01. The best score is 0.246349.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2011-11-01 to 2012-01-01. The best score is 0.225137.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 5, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2012-02-01 to 2012-04-01. The best score is 0.342338.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 3, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2012-05-01 to 2012-07-01. The best score is 0.359513.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 17, 'n_estimators': 5, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2012-08-01 to 2012-10-01. The best score is 0.414179.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 11, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2012-11-01 to 2013-01-01. The best score is 0.31715.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2013-02-01 to 2013-04-01. The best score is 0.336359.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 10, 'n_estimators': 15, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2013-05-01 to 2013-07-01. The best score is 0.334093.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2013-08-01 to 2013-10-01. The best score is 0.383763.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2013-11-01 to 2014-01-01. The best score is 0.292961.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 30, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2014-02-01 to 2014-04-01. The best score is 0.379067.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 9, 'n_estimators': 30, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2014-05-01 to 2014-07-01. The best score is 0.490294.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 14, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2014-08-01 to 2014-10-01. The best score is 0.394827.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 11, 'n_estimators': 25, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2014-11-01 to 2015-01-01. The best score is 0.471818.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 15, 'n_estimators': 35, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2015-02-01 to 2015-04-01. The best score is 0.551971.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2015-05-01 to 2015-07-01. The best score is 0.565379.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 12, 'n_estimators': 35, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2015-08-01 to 2015-10-01. The best score is 0.470141.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 13, 'n_estimators': 20, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2015-11-01 to 2016-01-01. The best score is 0.439912.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'n_estimators': 25, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2016-02-01 to 2016-04-01. The best score is 0.481018.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 30, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2016-05-01 to 2016-07-01. The best score is 0.472984.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 17, 'n_estimators': 15, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2016-08-01 to 2016-10-01. The best score is 0.481824.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 13, 'n_estimators': 30, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2016-11-01 to 2017-01-01. The best score is 0.419518.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 15, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2017-02-01 to 2017-04-01. The best score is 0.421173.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 11, 'n_estimators': 10, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2017-05-01 to 2017-07-01. The best score is 0.399993.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 19, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2017-08-01 to 2017-10-01. The best score is 0.416597.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 18, 'n_estimators': 25, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2017-11-01 to 2018-01-01. The best score is 0.310837.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 5, 'n_estimators': 10, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2018-02-01 to 2018-04-01. The best score is 0.241041.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 10, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2018-05-01 to 2018-07-01. The best score is -0.739916.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 16, 'n_estimators': 3, 'warm_start': True}
# ----------------------------------------------------------------------------------------------------
# Saved the fully-paid model for period 2018-08-01 to 2018-10-01. The best score is 0.166426.
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 6, 'n_estimators': 3, 'warm_start': False}
# ----------------------------------------------------------------------------------------------------
# Wall time: 3h 18min 9s

# %% [markdown]
# ### Load the pickle file and predict default probability with the saved models - for Nov. and Dec. 2018 issued current loans

# %%
filename_pkl = './model_test.pkl'
file = open(filename_pkl, 'wb')

# %%
pickle.dump(grid_search_rf, file)

# %%
file.close()

# %%
def pickleLoader(pklFile):
    try:
        while True:
            yield pickle.load(pklFile)
    except EOFError:
        pass

# %%
file = open('./model_test.pkl', 'rb')

# %%
for model in pickleLoader(file):
    print(model.predict_proba(df_window_x))

# %%
file.close()

# %%
df_window_y

# %%
model1.best_params_

# %%
model2.best_params_

# %%
model.best_params_
